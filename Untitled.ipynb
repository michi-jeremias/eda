# %%
from pathlib import Path
import pandas as pd

# %%
PATH = Path('../data/houseprice/')

# %%
dftrain = pd.read_csv(PATH/'train.csv')

# %%
dftrain.shape
# Out:
# (1460, 81)

# %%
dftrain.iloc[:,0]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64

# %%
dftrain.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
isinstance(dftrain, pd.DataFrame)
# Out:
# True

# %%
dftrain.drop('Id', axis=1, inplace=True)

# %%
dftrain.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
from eda import DataMangler
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_style("white")

# %%
class DataMangler:
    def __init__(self, data):
        self.data = data if isinstance(data, pd.DataFrame) else pd.DataFrame(data)

    def drop(self, col):
        if not isinstance(list, col):
            col = [col]

        try:
            for c in col:
                self.data.drop(c, inplace=True)
        except IndexError:
            print('Invalid index')

    def eda(self):
        print(f"Data:\n\
                Shape: \t{self.data.shape}\n\
                ")
        for col in self.data.columns:
            print(f"'{col}':\n\
                  Num Unique: \t\t{self.data[col].nunique()}\n\
                  First 10 Unique: \t{self.data[col].unique()[:10]}\n\
                  Type: \t\t{self.data[col].dtype}\n\
                  Missing total \t{self.data[col].isnull().sum()}\n\
                  Missing relative: \t{round(100*self.data[col].isnull().sum()/self.data.shape[0], 2)}%\n\
                  ")
    
    def plot(self):
        for col in self.data.columns:
            # if self.data[col].dtype == 'int64' or 'float64':
            # if self.data[col].dtype == 'float64':
            sns.histplot(self.data[col], color="dodgerblue", label="Compact")

# %%
dm = DataMangler(dftrain)

# %%
dftrain['Alley'].fillna('Missing', inplace=True)

# %%
dftrain['Alley'].isnull().sum()
# Out:
# 0

# %%
# plt.figure(figsize=(5,3), dpi = 100)
sns.histplot(dftrain['LotFrontage'], color="dodgerblue")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='Count'>

# %%
dm.eda()
# Out:
# Data:
#                 Shape: 	(1460, 80)
#
# 'MSSubClass':
#                   Num Unique: 		15
#                   First 10 Unique: 	[ 60  20  70  50 190  45  90 120  30  85]
#                   Type: 		int64
#                   Missing total 	0
#                   Missing relative: 	0.0%
#
# 'MSZoning':
#                   Num Unique: 		5
#                   First 10 Unique: 	['RL' 'RM' 'C (all)' 'FV' 'RH']
#                   Type: 		object
#                   Missing total 	0
#                   Missing relative: 	0.0%
#
# 'LotFrontage':
#                   Num Unique: 		110
#                   First 10 Unique: 	[65. 80. 68. 60. 84. 85. 75. nan 51. 50.]
#                   Type: 		float64
#                   Missing total 	259
#                   Missing relative: 	17.74%
#
# 'LotArea':
#                   Num Unique: 		1073
#                   First 10 Unique: 	[ 8450  9600 11250  9550 14260 14115 10084 10382  6120  7420]
#                   Type: 		int64
# ...

# %%
dm.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\miniconda3\envs\fastai2\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1519         try:
# -> 1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
#
# ~\miniconda3\envs\fastai2\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      60         # force an update so it also does type checking
# ---> 61         unit.update(values)
#      62         return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# ~\miniconda3\envs\fastai2\lib\site-packages\matplotlib\category.py in update(self, data)
#     210             # OrderedDict just iterates over unique values in data.
# --> 211             cbook._check_isinstance((str, bytes), value=val)
#     212             if convertible:
#
# ...

# %%
dm.eda()
# Out:
# Data:
#                 Shape: 	(1460, 80)
#
# 'MSSubClass':
#                   Num Unique: 		15
#                   First 10 Unique: 	[ 60  20  70  50 190  45  90 120  30  85]
#                   Type: 		int64
#                   Missing total 	0
#                   Missing relative: 	0.0%
#
# 'MSZoning':
#                   Num Unique: 		5
#                   First 10 Unique: 	['RL' 'RM' 'C (all)' 'FV' 'RH']
#                   Type: 		object
#                   Missing total 	0
#                   Missing relative: 	0.0%
#
# 'LotFrontage':
#                   Num Unique: 		110
#                   First 10 Unique: 	[65. 80. 68. 60. 84. 85. 75. nan 51. 50.]
#                   Type: 		float64
#                   Missing total 	259
#                   Missing relative: 	17.74%
#
# 'LotArea':
#                   Num Unique: 		1073
#                   First 10 Unique: 	[ 8450  9600 11250  9550 14260 14115 10084 10382  6120  7420]
#                   Type: 		int64
# ...

# %%
for col in dftrain.columns:
    print(dftrain[col].nunique())
# Out:
# 15
# 5
# 110
# 1073
# 2
# 2
# 4
# 4
# 2
# 5
# 3
# 25
# 9
# 8
# 5
# 8
# 10
# 9
# 112
# 61
# 6
# 8
# 15
# 16
# 4
# 327
# 4
# 5
# 6
# 4
# 4
# 4
# 6
# 637
# 6
# 144
# 780
# 721
# 6
# 5
# 2
# 5
# 753
# 417
# 24
# 861
# 4
# 3
# 4
# 3
# 8
# 4
# 4
# 12
# 7
# 4
# 5
# 6
# 97
# 3
# 5
# 441
# 5
# 5
# 3
# 274
# 202
# 120
# 20
# 76
# 8
# 3
# 4
# 4
# 21
# 12
# 5
# 9
# 6
# 663
